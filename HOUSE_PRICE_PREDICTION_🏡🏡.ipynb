# %% [markdown]
# <a href="https://colab.research.google.com/github/githubleelabobby/House-Price-Prediction-ML-Project/blob/main/HOUSE_PRICE_PREDICTION_%F0%9F%8F%A1%F0%9F%8F%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **🏡🏡HOUSE PRICE PREDICTION 🏡🏡!!!**

# %% [markdown]
# ##1.Loading and Reading Data

# %%
import pandas as pd
fed_files=["https://raw.githubusercontent.com/dataquestio/project-walkthroughs/master/house_prices/MORTGAGE30US.csv" , "https://raw.githubusercontent.com/dataquestio/project-walkthroughs/master/house_prices/RRVRUSQ156N.csv" , "https://raw.githubusercontent.com/dataquestio/project-walkthroughs/master/house_prices/CPIAUCSL.csv",]
dfs=[pd.read_csv(f,parse_dates=True , index_col=0) for f in fed_files]

# %%
dfs[0]
# Out:
#             MORTGAGE30US
# DATE
# 1971-04-02          7.33
# 1971-04-09          7.31
# 1971-04-16          7.31
# 1971-04-23          7.31
# 1971-04-30          7.29
# ...                  ...
# 2022-07-14          5.51
# 2022-07-21          5.54
# 2022-07-28          5.30
# 2022-08-04          4.99
# 2022-08-11          5.22
#
# [2681 rows x 1 columns]

# %%
dfs[1]
# Out:
#             RRVRUSQ156N
# DATE
# 1956-01-01          6.2
# 1956-04-01          5.9
# 1956-07-01          6.3
# 1956-10-01          5.8
# 1957-01-01          5.3
# ...                 ...
# 2021-04-01          6.2
# 2021-07-01          5.8
# 2021-10-01          5.6
# 2022-01-01          5.8
# 2022-04-01          5.6
#
# [266 rows x 1 columns]

# %%
dfs[2]
# Out:
#             CPIAUCSL
# DATE
# 1947-01-01    21.480
# 1947-02-01    21.620
# 1947-03-01    22.000
# 1947-04-01    22.000
# 1947-05-01    21.950
# ...              ...
# 2022-03-01   287.708
# 2022-04-01   288.663
# 2022-05-01   291.474
# 2022-06-01   295.328
# 2022-07-01   295.271
#
# [907 rows x 1 columns]

# %% [markdown]
# ## 2.Merging Timeline to Get a Single Dataframe 🕰️=>📈 !!!

# %%
fed_data = pd.concat ( dfs , axis = 1)

# %%
fed_data
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 1947-01-01           NaN          NaN     21.48
# 1947-02-01           NaN          NaN     21.62
# 1947-03-01           NaN          NaN     22.00
# 1947-04-01           NaN          NaN     22.00
# 1947-05-01           NaN          NaN     21.95
# ...                  ...          ...       ...
# 2022-07-14          5.51          NaN       NaN
# 2022-07-21          5.54          NaN       NaN
# 2022-07-28          5.30          NaN       NaN
# 2022-08-04          4.99          NaN       NaN
# 2022-08-11          5.22          NaN       NaN
#
# [3507 rows x 3 columns]

# %%
fed_data.tail(50)  #to get last 50 rows
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 2021-11-01           NaN          NaN   278.524
# 2021-11-04          3.09          NaN       NaN
# 2021-11-10          2.98          NaN       NaN
# 2021-11-18          3.10          NaN       NaN
# 2021-11-24          3.10          NaN       NaN
# 2021-12-01           NaN          NaN   280.126
# 2021-12-02          3.11          NaN       NaN
# 2021-12-09          3.10          NaN       NaN
# 2021-12-16          3.12          NaN       NaN
# 2021-12-23          3.05          NaN       NaN
# 2021-12-30          3.11          NaN       NaN
# 2022-01-01           NaN          5.8   281.933
# 2022-01-06          3.22          NaN       NaN
# 2022-01-13          3.45          NaN       NaN
# 2022-01-20          3.56          NaN       NaN
# 2022-01-27          3.55          NaN       NaN
# 2022-02-01           NaN          NaN   284.182
# 2022-02-03          3.55          NaN       NaN
# ...

# %% [markdown]
# ##3.Forward Filling with Recent Rental Rates ⏩

# %%
fed_data = fed_data.ffill()

# %%
fed_data.tail(50)
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 2021-11-01          3.14          5.6   278.524
# 2021-11-04          3.09          5.6   278.524
# 2021-11-10          2.98          5.6   278.524
# 2021-11-18          3.10          5.6   278.524
# 2021-11-24          3.10          5.6   278.524
# 2021-12-01          3.10          5.6   280.126
# 2021-12-02          3.11          5.6   280.126
# 2021-12-09          3.10          5.6   280.126
# 2021-12-16          3.12          5.6   280.126
# 2021-12-23          3.05          5.6   280.126
# 2021-12-30          3.11          5.6   280.126
# 2022-01-01          3.11          5.8   281.933
# 2022-01-06          3.22          5.8   281.933
# 2022-01-13          3.45          5.8   281.933
# 2022-01-20          3.56          5.8   281.933
# 2022-01-27          3.55          5.8   281.933
# 2022-02-01          3.55          5.8   284.182
# 2022-02-03          3.55          5.8   284.182
# ...

# %% [markdown]
# # **⏳ Loading Zillow House Price Data **

# %%
zillow_files=["https://raw.githubusercontent.com/dataquestio/project-walkthroughs/master/house_prices/Metro_median_sale_price_uc_sfrcondo_week.csv" , "https://raw.githubusercontent.com/dataquestio/project-walkthroughs/master/house_prices/Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_month.csv" ]

dfs = [pd.read_csv(f) for f in zillow_files]

# %%
dfs[0]
# Out:
#     RegionID  SizeRank                          RegionName RegionType  \
# 0     102001         0                       United States    Country
# 1     394913         1                        New York, NY        Msa
# 2     753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3     394463         3                         Chicago, IL        Msa
# 4     394514         4               Dallas-Fort Worth, TX        Msa
# ..       ...       ...                                 ...        ...
# 79    394528        90                   Daytona Beach, FL        Msa
# 80    394531        91                      Des Moines, IA        Msa
# 81    395006       100                           Provo, UT        Msa
# 82    394549       104                          Durham, NC        Msa
# 83    394602       159                    Fort Collins, CO        Msa
#
#    StateName  2008-02-02  2008-02-09  2008-02-16  2008-02-23  2008-03-01  ...  \
# ...

# %% [markdown]
# ##(i) Creating Month Column to Merge 2 DataFrames➕

# %%
dfs = [pd.DataFrame(df.iloc[0,5:]) for df in dfs]

# %%
dfs[0]   # house price data => comes out every week
# Out:
#                    0
# 2008-02-02  190000.0
# 2008-02-09  190000.0
# 2008-02-16  193000.0
# 2008-02-23  189900.0
# 2008-03-01  194900.0
# ...              ...
# 2022-06-11  370000.0
# 2022-06-18  375000.0
# 2022-06-25  370000.0
# 2022-07-02  370000.0
# 2022-07-09  362500.0
#
# [754 rows x 1 columns]

# %%
dfs[1]   # house value data => only comes out once a month
# Out:
#                         0
# 1996-01-31  108641.264685
# 1996-02-29   108472.72888
# 1996-03-31  108532.280074
# 1996-04-30  108739.077466
# 1996-05-31  108986.621607
# ...                   ...
# 2022-03-31  344042.433111
# 2022-04-30  350515.841789
# 2022-05-31  354717.722904
# 2022-06-30  357473.327397
# 2022-07-31  357107.271636
#
# [319 rows x 1 columns]

# %%
for df in dfs:
  df.index = pd.to_datetime(df.index)
  df["month"] = df.index.to_period("M")

# %%
dfs[0]
# Out:
#                    0    month
# 2008-02-02  190000.0  2008-02
# 2008-02-09  190000.0  2008-02
# 2008-02-16  193000.0  2008-02
# 2008-02-23  189900.0  2008-02
# 2008-03-01  194900.0  2008-03
# ...              ...      ...
# 2022-06-11  370000.0  2022-06
# 2022-06-18  375000.0  2022-06
# 2022-06-25  370000.0  2022-06
# 2022-07-02  370000.0  2022-07
# 2022-07-09  362500.0  2022-07
#
# [754 rows x 2 columns]

# %%
dfs[1]
# Out:
#                         0    month
# 1996-01-31  108641.264685  1996-01
# 1996-02-29   108472.72888  1996-02
# 1996-03-31  108532.280074  1996-03
# 1996-04-30  108739.077466  1996-04
# 1996-05-31  108986.621607  1996-05
# ...                   ...      ...
# 2022-03-31  344042.433111  2022-03
# 2022-04-30  350515.841789  2022-04
# 2022-05-31  354717.722904  2022-05
# 2022-06-30  357473.327397  2022-06
# 2022-07-31  357107.271636  2022-07
#
# [319 rows x 2 columns]

# %%
price_data = dfs[0].merge( dfs[1] , on = "month" )

# %%
price_data.index = dfs[0].index

# %%
price_data
# Out:
#                  0_x    month            0_y
# 2008-02-02  190000.0  2008-02  206885.853266
# 2008-02-09  190000.0  2008-02  206885.853266
# 2008-02-16  193000.0  2008-02  206885.853266
# 2008-02-23  189900.0  2008-02  206885.853266
# 2008-03-01  194900.0  2008-03  205459.521952
# ...              ...      ...            ...
# 2022-06-11  370000.0  2022-06  357473.327397
# 2022-06-18  375000.0  2022-06  357473.327397
# 2022-06-25  370000.0  2022-06  357473.327397
# 2022-07-02  370000.0  2022-07  357107.271636
# 2022-07-09  362500.0  2022-07  357107.271636
#
# [754 rows x 3 columns]

# %% [markdown]
# ##(ii) Renaming The Columns ✏️📋

# %%
del price_data["month"]
price_data.columns=["price","value"]

# %%
price_data
# Out:
#                price          value
# 2008-02-02  190000.0  206885.853266
# 2008-02-09  190000.0  206885.853266
# 2008-02-16  193000.0  206885.853266
# 2008-02-23  189900.0  206885.853266
# 2008-03-01  194900.0  205459.521952
# ...              ...            ...
# 2022-06-11  370000.0  357473.327397
# 2022-06-18  375000.0  357473.327397
# 2022-06-25  370000.0  357473.327397
# 2022-07-02  370000.0  357107.271636
# 2022-07-09  362500.0  357107.271636
#
# [754 rows x 2 columns]

# %% [markdown]
# #=>PREPARING DATA FOR MACHINE LEARNING 🛠️

# %%
fed_data = fed_data.dropna()

# %%
fed_data  #now we have data with only all three indicators
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 1971-04-02          7.33          5.3    40.100
# 1971-04-09          7.31          5.3    40.100
# 1971-04-16          7.31          5.3    40.100
# 1971-04-23          7.31          5.3    40.100
# 1971-04-30          7.29          5.3    40.100
# ...                  ...          ...       ...
# 2022-07-14          5.51          5.6   295.271
# 2022-07-21          5.54          5.6   295.271
# 2022-07-28          5.30          5.6   295.271
# 2022-08-04          4.99          5.6   295.271
# 2022-08-11          5.22          5.6   295.271
#
# [3215 rows x 3 columns]

# %%
fed_data.tail(20)
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 2022-04-21          5.11          5.6   288.663
# 2022-04-28          5.10          5.6   288.663
# 2022-05-01          5.10          5.6   291.474
# 2022-05-05          5.27          5.6   291.474
# 2022-05-12          5.30          5.6   291.474
# 2022-05-19          5.25          5.6   291.474
# 2022-05-26          5.10          5.6   291.474
# 2022-06-01          5.10          5.6   295.328
# 2022-06-02          5.09          5.6   295.328
# 2022-06-09          5.23          5.6   295.328
# 2022-06-16          5.78          5.6   295.328
# 2022-06-23          5.81          5.6   295.328
# 2022-06-30          5.70          5.6   295.328
# 2022-07-01          5.70          5.6   295.271
# 2022-07-07          5.30          5.6   295.271
# 2022-07-14          5.51          5.6   295.271
# 2022-07-21          5.54          5.6   295.271
# 2022-07-28          5.30          5.6   295.271
# ...

# %% [markdown]
# ##Aligning "ZILLOW" and "FED" Data 🏡

# %%
'''Federal reserve releases all its data on Tuesdays wheras Zillow Releases all its data on Thursdays
and hence we need to align Zillow Data with Fed data'''
from datetime import timedelta

fed_data.index = fed_data.index + timedelta(days=2)

# %%
fed_data
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# DATE
# 1971-04-04          7.33          5.3    40.100
# 1971-04-11          7.31          5.3    40.100
# 1971-04-18          7.31          5.3    40.100
# 1971-04-25          7.31          5.3    40.100
# 1971-05-02          7.29          5.3    40.100
# ...                  ...          ...       ...
# 2022-07-16          5.51          5.6   295.271
# 2022-07-23          5.54          5.6   295.271
# 2022-07-30          5.30          5.6   295.271
# 2022-08-06          4.99          5.6   295.271
# 2022-08-13          5.22          5.6   295.271
#
# [3215 rows x 3 columns]

# %%
price_data = fed_data.merge(price_data , left_index = True , right_index = True)

# %%
price_data
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL     price          value
# 2008-02-02          5.68         10.1   212.174  190000.0  206885.853266
# 2008-02-09          5.67         10.1   212.687  190000.0  206885.853266
# 2008-02-16          5.72         10.1   212.687  193000.0  206885.853266
# 2008-02-23          6.04         10.1   212.687  189900.0  206885.853266
# 2008-03-01          6.24         10.1   212.687  194900.0  205459.521952
# ...                  ...          ...       ...       ...            ...
# 2022-06-11          5.23          5.6   295.328  370000.0  357473.327397
# 2022-06-18          5.78          5.6   295.328  375000.0  357473.327397
# 2022-06-25          5.81          5.6   295.328  370000.0  357473.327397
# 2022-07-02          5.70          5.6   295.328  370000.0  357107.271636
# 2022-07-09          5.30          5.6   295.271  362500.0  357107.271636
#
# [735 rows x 5 columns]

# %% [markdown]
# ## Renaming The Columns ✏️📋

# %%
price_data.columns = ["interest","vacancy","cpi","price","value"]

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value
# 2008-02-02      5.68     10.1  212.174  190000.0  206885.853266
# 2008-02-09      5.67     10.1  212.687  190000.0  206885.853266
# 2008-02-16      5.72     10.1  212.687  193000.0  206885.853266
# 2008-02-23      6.04     10.1  212.687  189900.0  206885.853266
# 2008-03-01      6.24     10.1  212.687  194900.0  205459.521952
# ...              ...      ...      ...       ...            ...
# 2022-06-11      5.23      5.6  295.328  370000.0  357473.327397
# 2022-06-18      5.78      5.6  295.328  375000.0  357473.327397
# 2022-06-25      5.81      5.6  295.328  370000.0  357473.327397
# 2022-07-02      5.70      5.6  295.328  370000.0  357107.271636
# 2022-07-09      5.30      5.6  295.271  362500.0  357107.271636
#
# [735 rows x 5 columns]

# %% [markdown]
# # **=>SETTING UP OUR MACHINE LEARNING TARGET🛠️**

# %%
price_data.plot.line( y="price" , use_index=True , color="#FF1493")
# Out:
# <Axes: >

# %%
price_data["adj_price"] = price_data["price"] / price_data["cpi"] * 100

# %%
price_data.plot.line(y="adj_price" , use_index=True ,color="#39FF14")
# Out:
# <Axes: >

# %%
price_data["adj_value"] = price_data["value"] / price_data["cpi"] * 100

# %%
price_data["next_quarter"] = price_data["adj_price"].shift(-13)

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value  \
# 2008-02-02      5.68     10.1  212.174  190000.0  206885.853266
# 2008-02-09      5.67     10.1  212.687  190000.0  206885.853266
# 2008-02-16      5.72     10.1  212.687  193000.0  206885.853266
# 2008-02-23      6.04     10.1  212.687  189900.0  206885.853266
# 2008-03-01      6.24     10.1  212.687  194900.0  205459.521952
# ...              ...      ...      ...       ...            ...
# 2022-06-11      5.23      5.6  295.328  370000.0  357473.327397
# 2022-06-18      5.78      5.6  295.328  375000.0  357473.327397
# 2022-06-25      5.81      5.6  295.328  370000.0  357473.327397
# 2022-07-02      5.70      5.6  295.328  370000.0  357107.271636
# 2022-07-09      5.30      5.6  295.271  362500.0  357107.271636
#
#                 adj_price      adj_value  next_quarter
# 2008-02-02   89549.143627   97507.636782  90610.014498
# 2008-02-09   89333.151533   97272.448841  90563.547824
# ...

# %%
price_data.dropna(inplace=True)

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value  \
# 2008-02-02      5.68     10.1  212.174  190000.0  206885.853266
# 2008-02-09      5.67     10.1  212.687  190000.0  206885.853266
# 2008-02-16      5.72     10.1  212.687  193000.0  206885.853266
# 2008-02-23      6.04     10.1  212.687  189900.0  206885.853266
# 2008-03-01      6.24     10.1  212.687  194900.0  205459.521952
# ...              ...      ...      ...       ...            ...
# 2022-03-12      3.85      5.8  287.708  350000.0  344042.433111
# 2022-03-19      4.16      5.8  287.708  350000.0  344042.433111
# 2022-03-26      4.42      5.8  287.708  355000.0  344042.433111
# 2022-04-02      4.67      5.8  287.708  360000.0  350515.841789
# 2022-04-09      4.72      5.6  288.663  365000.0  350515.841789
#
#                 adj_price      adj_value   next_quarter
# 2008-02-02   89549.143627   97507.636782   90610.014498
# 2008-02-09   89333.151533   97272.448841   90563.547824
# ...

# %%
price_data["change"] = (price_data["next_quarter"] > price_data["adj_price"]).astype(int)

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value  \
# 2008-02-02      5.68     10.1  212.174  190000.0  206885.853266
# 2008-02-09      5.67     10.1  212.687  190000.0  206885.853266
# 2008-02-16      5.72     10.1  212.687  193000.0  206885.853266
# 2008-02-23      6.04     10.1  212.687  189900.0  206885.853266
# 2008-03-01      6.24     10.1  212.687  194900.0  205459.521952
# ...              ...      ...      ...       ...            ...
# 2022-03-12      3.85      5.8  287.708  350000.0  344042.433111
# 2022-03-19      4.16      5.8  287.708  350000.0  344042.433111
# 2022-03-26      4.42      5.8  287.708  355000.0  344042.433111
# 2022-04-02      4.67      5.8  287.708  360000.0  350515.841789
# 2022-04-09      4.72      5.6  288.663  365000.0  350515.841789
#
#                 adj_price      adj_value   next_quarter  change
# 2008-02-02   89549.143627   97507.636782   90610.014498       1
# 2008-02-09   89333.151533   97272.448841   90563.547824       1
# ...

# %%
price_data["change"].value_counts()
# Out:
# change
# 1    379
# 0    343
# Name: count, dtype: int64

# %%
predictors = ["interest" , "vacancy" , "adj_price" , "adj_value"]
target = "change"

# %% [markdown]
# # **CREATING A MACHINE LEARNING MODEL🏗️ **

# %% [markdown]
# ##  Training,  Testing,  Predicting , and  Targeting Data

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import numpy as np

# %%
def predict(train , test , predictors , target ) :
  rf=RandomForestClassifier(min_samples_split= 10 , random_state = 1)
  rf.fit(train[predictors] , train[target])
  preds = rf.predict(test[predictors])
  return preds

# %% [markdown]
# # =>CREATING A BACKTESTING ENGINE 🕰️🧑‍💻

# %%
START=260
STEP=52
def backtest(data,predictors,target):
  all_preds=[]
  for i in range(START, data.shape[0],STEP):
    train = price_data.iloc[:i]
    test=price_data.iloc[i:(i+STEP)]
    all_preds.append(predict(train,test,predictors,target))
  preds = np.concatenate(all_preds)
  return preds , accuracy_score(data.iloc[START:][target] , preds)

# %% [markdown]
# # **📏 Measuring Error ❌**

# %% [markdown]
# ## ✔️ Checking Current Accuracy 🎯

# %%
preds, accuracy = backtest(price_data,predictors, target)

# %%
accuracy
# Out:
# 0.5952380952380952

# %% [markdown]
# # ** IMPROVING CUREENT ACCURACY 🌟**

# %%
yearly = price_data.rolling(52, min_periods=1).mean()

# %%
yearly
# Out:
#             interest    vacancy         cpi          price          value  \
# 2008-02-02  5.680000  10.100000  212.174000  190000.000000  206885.853266
# 2008-02-09  5.675000  10.100000  212.430500  190000.000000  206885.853266
# 2008-02-16  5.690000  10.100000  212.516000  191000.000000  206885.853266
# 2008-02-23  5.777500  10.100000  212.558750  190725.000000  206885.853266
# 2008-03-01  5.870000  10.100000  212.584400  191560.000000  206600.587003
# ...              ...        ...         ...            ...            ...
# 2022-03-12  3.115000   5.934615  274.619904  327174.057692  313200.591987
# 2022-03-19  3.136923   5.915385  275.056058  328135.596154  314338.764087
# 2022-03-26  3.163269   5.896154  275.492212  329193.288462  315476.936188
# 2022-04-02  3.193654   5.876923  275.928365  330250.980769  316739.596917
# 2022-04-09  3.223462   5.853846  276.382885  331347.134615  318002.257646
#
#                 adj_price      adj_value   next_quarter    change
# ...

# %% [markdown]
# ##Predicting Ratio Of Current Year 📅↔️🗓️ And Past Year

# %%
yearly_ratios = [p+ "_year" for p in predictors]
price_data[yearly_ratios] = price_data[predictors] / yearly[predictors]

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value  \
# 2008-02-02      5.68     10.1  212.174  190000.0  206885.853266
# 2008-02-09      5.67     10.1  212.687  190000.0  206885.853266
# 2008-02-16      5.72     10.1  212.687  193000.0  206885.853266
# 2008-02-23      6.04     10.1  212.687  189900.0  206885.853266
# 2008-03-01      6.24     10.1  212.687  194900.0  205459.521952
# ...              ...      ...      ...       ...            ...
# 2022-03-12      3.85      5.8  287.708  350000.0  344042.433111
# 2022-03-19      4.16      5.8  287.708  350000.0  344042.433111
# 2022-03-26      4.42      5.8  287.708  355000.0  344042.433111
# 2022-04-02      4.67      5.8  287.708  360000.0  350515.841789
# 2022-04-09      4.72      5.6  288.663  365000.0  350515.841789
#
#                 adj_price      adj_value   next_quarter  change  \
# 2008-02-02   89549.143627   97507.636782   90610.014498       1
# 2008-02-09   89333.151533   97272.448841   90563.547824       1
# ...

# %%
preds , accuracy = backtest( price_data , predictors + yearly_ratios , target )

# %%
accuracy
# Out:
# 0.6536796536796536

# %% [markdown]
# # **RUNNING DIAGNOSTICS ON OUR MODEL 🩺**

# %%
pred_match = (preds == price_data[target].iloc[START:])

# %%
pred_match[pred_match == True]= "#FF1493"
pred_match[pred_match == False]="#0000FF"

# %%
import matplotlib.pyplot as plt

plot_data = price_data.iloc[START:].copy()

plot_data.reset_index().plot.scatter(x="index" , y="adj_price" , color=pred_match)
# Out:
# <Axes: xlabel='index', ylabel='adj_price'>

# %% [markdown]
# ##✅ Final Diagnostic

# %%
from sklearn.inspection import permutation_importance

rf=RandomForestClassifier(min_samples_split=10 , random_state =1)
rf.fit(price_data[predictors], price_data[target])

result = permutation_importance(rf,price_data[predictors] ,price_data[target], n_repeats = 10 , random_state=1 )

# %%
result["importances_mean"]
# Out:
# array([0.17451524, 0.15540166, 0.27576177, 0.34861496])

# %%
predictors
# Out:
# ['interest', 'vacancy', 'adj_price', 'adj_value']

# %% [markdown]
# # **🎉🎉THE PREDICTION ADVENTURE ENDS HERE !!!!!🎉🎉*
